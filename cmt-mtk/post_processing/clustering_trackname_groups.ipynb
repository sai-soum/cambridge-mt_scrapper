# %%
# !pip install scikit-learn
# !pip install pyyaml
# !pip install gensim
# !pip install plotly
# !pip install pandas
# !pip install numpy
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy>=1.19.5 (from scikit-learn)
#   Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 20.7 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 50.1 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 60.5 MB/s eta 0:00:0000:0100:01
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# Successfully installed joblib-1.4.2 numpy-2.2.2 scikit-learn-1.6.1 scipy-1.15.1 threadpoolctl-3.5.0
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/pyyaml/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/pyyaml/
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 28.8 MB/s eta 0:00:00
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0.2
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 20.3 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 25.8 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 33.1 MB/s eta 0:00:00a 0:00:01
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.1
#     Uninstalling scipy-1.15.1:
#       Successfully uninstalled scipy-1.15.1
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1 smart-open-7.1.0 wrapt-1.17.2
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.24.1-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: packaging in /home/soumya/.venv/lib/python3.11/site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 56.1 MB/s eta 0:00:00a 0:00:01
# Downloading narwhals-1.24.1-py3-none-any.whl (309 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.24.1 plotly-6.0.0
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/pandas/
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.23.2 in /home/soumya/.venv/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/soumya/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/soumya/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 69.2 MB/s eta 0:00:00
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2025.1
# Requirement already satisfied: numpy in /home/soumya/.venv/lib/python3.11/site-packages (1.26.4)

# %%
# lets just open all the .yaml files and copy the dictionary values to a new file
import os
import glob
import yaml
import re
import numpy as np
import pandas as pd
import gensim.downloader as api
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
import plotly.express as px
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# Step 1: Preprocessing - Add a space between lowercase and uppercase
def add_space_between_cases(text):
    return re.sub(r'([a-z])([A-Z])', r'\1 \2', text)

# Step 2: Load Word2Vec model (pre-trained)
# You can download a smaller model like "glove-wiki-gigaword-50" if you need faster performance.
word2vec_model = api.load("glove-wiki-gigaword-50")  # 50-dimensional word vectors

# Step 3: Convert names to vectors using Word2Vec
def get_word2vec_vector(text, model):
    words = text.lower().split()  # Tokenize and make lowercase
    vector = np.zeros((model.vector_size,))  # Initialize with zeros
    valid_words = 0
    
    for word in words:
        if word in model:
            vector += model[word]
            valid_words += 1
            
    if valid_words > 0:
        vector /= valid_words  # Average the vectors of words
    return vector

# %%
# Step 4: Generate embeddings for the list of names
with open("/home/soumya/cambridge-mt_scrapper/data/post-processing/unique_cleaned_trackname_metadata.txt", "r") as f:
        names = f.readlines()
        names = [name.strip() for name in names]
# Preprocess names by adding spaces between lowercase and uppercase
processed_names = [add_space_between_cases(name) for name in names]
print(processed_names[:15])
# Out:
# ['Horn', 'Cymbals OD', 'Drums Snare Up', 'BASS CAB   CU  copperhead   BAE', 'Kick SFX', 'RIde', 'Saxophone Close Mic', 'Elec Piano SFX', 'Bass FX', 'Hi Hat Ride', 'Vocals Erica M', 'Cymbal Swells', 'Vocals Acoustic Guitar Proto', 'AC GUITAR', 'Backing Vox DT']

# %%
# Generate Word2Vec embeddings for each name
embeddings = np.array([get_word2vec_vector(name, word2vec_model) for name in processed_names])
print("Embeddings: ", embeddings)
# Step 5: Normalize the embeddings (if necessary)
# This step can help improve DBSCAN performance, especially if cosine similarity is used.
embeddings_normalized = normalize(embeddings)


# fig.write_html("word2vec_clusters.html")
# Out:
# Embeddings:  [[-0.024018   -0.30223    -0.63186002 ... -0.23839    -0.51620001
#   -0.29591   ]
#  [-0.93992999 -0.52413101 -0.44327401 ... -0.26174551  0.22575501
#   -0.32693002]
#  [-0.44563799 -0.47118667  0.35877199 ... -0.64918666 -0.777698
#   -0.38596332]
#  ...
#  [-0.42752665  0.10849666  0.04459867 ... -0.65335665 -0.58712767
#   -0.24241332]
#  [-0.26964    -0.48569    -0.21484999 ... -0.36733001 -0.1663
#   -1.15509999]
#  [-0.37262     0.40030668  0.98552    ... -0.50115333 -0.21622333
#    0.03370667]]

# %%
# Step 6: Apply DBSCAN clustering
db = DBSCAN(metric='cosine', eps=0.2, min_samples=2)  # Adjust eps and min_samples if needed
labels = db.fit_predict(embeddings_normalized)
print(labels)
# print("Labels: ", labels)
# Out:
# [-1  0  0 ...  0  0  0]

# %%
# Step 7: Dimensionality Reduction (PCA or t-SNE)
# Here, we'll use both PCA and t-SNE for comparison
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings_normalized)
print("PCA Result: ", pca_result)
# Out:
# PCA Result:  [[ 0.1005133  -0.2279326 ]
#  [-0.52103845 -0.119463  ]
#  [ 0.28447555 -0.35254506]
#  ...
#  [ 0.23201897 -0.32172467]
#  [-0.11155117 -0.30218168]
#  [ 0.04775788  0.25805419]]

# %%
# !pip install ipykernel
# !pip install nbformat
import nbformat
# !pip install matplotlib
# Out:
# Requirement already satisfied: ipykernel in /home/soumya/.venv/lib/python3.11/site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (8.31.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/soumya/.venv/lib/python3.11/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/soumya/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/soumya/.venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/soumya/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/soumya/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/soumya/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/soumya/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/soumya/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/soumya/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/soumya/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /home/soumya/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: nbformat in /home/soumya/.venv/lib/python3.11/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/soumya/.venv/lib/python3.11/site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/soumya/.venv/lib/python3.11/site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/soumya/.venv/lib/python3.11/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /home/soumya/.venv/lib/python3.11/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/soumya/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/soumya/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/soumya/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/soumya/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/soumya/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/soumya/.venv/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.12.2)
# Requirement already satisfied: matplotlib in /home/soumya/.venv/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/soumya/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/soumya/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Alternatively, use t-SNE for more complex relationships
tsne = TSNE(n_components=2, perplexity=2)
tsne_result = tsne.fit_transform(embeddings_normalized)
import nbformat
import matplotlib.pyplot as plt

# Step 8: Plot interactive clusters using Plotly
# Create a DataFrame for plotting
# df = pd.DataFrame(pca_result, columns=["PC1", "PC2"])
# df['Cluster'] = labels
# df['Name'] = names

# # Plot clusters using Plotly
# fig = px.scatter(df, x="PC1", y="PC2", color="Cluster", hover_data=["Name"])
# fig.update_traces(marker=dict(size=5))
# fig.show()

# plot the tsne result
plt.figure(figsize=(10, 5))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=labels, cmap='viridis')
plt.colorbar()
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
# Step 1: Vectorize names using TF-IDF
vectorizer = TfidfVectorizer(lowercase=True, stop_words='english')
X = vectorizer.fit_transform(names)

# %%
print("X: ", X)
#
# Out:
# X:    (0, 524)	1.0
#   (1, 261)	1.0
#   (2, 346)	1.0
#   (3, 96)	0.3458261960662402
#   (3, 178)	0.5676561527956507
#   (3, 250)	0.33902990896343754
#   (3, 242)	0.5284513599496383
#   (3, 89)	0.40493038327991165
#   (4, 550)	0.6268065447118077
#   (4, 870)	0.7791749197108725
#   (5, 826)	1.0
#   (6, 856)	1.0
#   (7, 405)	1.0
#   (8, 115)	1.0
#   (9, 520)	1.0
#   (10, 1120)	0.5004546828819861
#   (10, 413)	0.8657627333060085
#   (11, 264)	1.0
#   (12, 1120)	0.44215631897114405
#   (12, 16)	0.5984664212871523
#   (12, 476)	0.4108953977191229
#   (12, 792)	0.5267833561521099
#   (13, 476)	0.5783335121701128
#   (13, 1)	0.8158004343593978
#   (14, 75)	1.0
#   :	:
#   (1786, 785)	1.0
#   (1787, 96)	0.5010157937088779
#   (1787, 49)	0.5866430006851352
#   (1787, 1025)	0.6362650109831622
#   (1788, 832)	1.0
#   (1789, 982)	1.0
#   (1790, 550)	0.2693578806676052
#   (1790, 1026)	0.40646674856893067
#   (1790, 587)	0.40646674856893067
#   (1790, 868)	0.4461000996554696
#   (1790, 1077)	0.4461000996554696
#   (1790, 790)	0.4461000996554696
#   (1791, 96)	0.7242291916780016
#   (1791, 275)	0.6895593360410899
#   (1792, 575)	1.0
#   (1793, 42)	0.6575885141311901
#   (1793, 326)	0.7533772933150651
#   (1794, 96)	0.46620656804517363
#   (1794, 275)	0.44388861318111095
#   (1794, 1019)	0.7652544250115061
#   (1795, 697)	0.6975566959914786
#   (1795, 326)	0.7165295917667686
#   (1796, 525)	1.0
#   (1797, 901)	0.6896961685521579
#   (1797, 878)	0.7240988848800095

# %%
# Step 2: Apply DBSCAN clustering
db = DBSCAN(metric='cosine', eps=0.2, min_samples=3)
labels = db.fit_predict(X)
print("Labels: ", labels)
# Out:
# Labels:  [-1 -1 -1 ... -1 -1  4]

# %%
# Step 3: Group names by cluster labels
clusters = {}
for idx, label in enumerate(labels):
    if label not in clusters:
        clusters[label] = []
    clusters[label].append(names[idx])

# Step 4: Print the grouped names
for cluster_id, group in clusters.items():
    print(f"Cluster {cluster_id}: {group}")
# Out:
# Cluster -1: ['Horn', 'CymbalsOD', 'DrumsSnareUp', 'BASS CAB   CU  copperhead   BAE', 'Kick SFX', 'SaxophoneCloseMic', 'ElecPianoSFX', 'BassFX', 'HiHatRide', 'Vocals Erica M', 'CymbalSwells', 'BackingVoxDT', 'DRUM OH AR LANGEVIN.L', 'LESLIE BOTTOM M', 'ElecGtra Mic', 'DrumsTom', 'Saxophone', 'PercLoop', 'LeadVoxAccents', 'Vocals Bone M', 'SFXLoop', 'LeadVoxMic', 'Drumkit RoomMono', 'BassClarinet', 'AcGtrDI', 'ElecGtra Close', 'RoomMono', 'Bulldozer', 'BassHi', 'SampleBrass', 'DoubleBass', 'Hat SFX', 'ROOM STEREO L   C w TFUNK CK   Neve', 'GlassBell', 'Clavinet', 'MIDIStrings', 'GUITAR AMP    M', 'BackingVoxa', 'LeadVoxTapeEffect', 'ReversePiano', 'BackingVoxBr', 'DrumsSideR', 'FloorTom', 'OfficeAmbience', 'BEATBOX ALTO B AK SSLE', 'LeadVox AltTake', 'BASS   DI    API', 'Vocals BGV M', 'VoxSFX', 'PIANO AK LANGEVIN.L', 'UkeleleMic', 'Loops', 'ViolaSamples', 'VoxGuitar', 'VOX BG U', 'LeadVoxCha', 'LeadVoxClose', 'HornsDT', 'RoomLoFi', 'BassPedals', 'RunningAsiza', 'LeadVoxVs', 'NBATG   acoustic guitar DI', 'Clicks', 'StringsPizz', 'MIDIViolin', 'BassAlt', 'Cowbell', 'Sax OD', 'CelloSamples', 'OverheadsIntro', 'DRUM RACK TOM M SSL DUALITY', 'Lead Vox B (AKG )', 'Rhythm Gtr', 'ElecGtrLead', 'Bass AlternateTake', 'DRUM OVERHEAD STEREO R   AR    Neve', 'Paul Amp M', 'Drumkit OverheadMono', 'Strings Violin Active DI', 'AcGtrReampFar', 'Idiophone', 'LeadVoxVsDT', 'ElecGtrDry', 'TreeChopFall', 'Vocals Tim CU', 'CymbalWash', 'DRUMS   Kick In   M SH', 'CellosAndBassesSpiccato', 'SaxMic', 'DrumKit', 'DrumsBreak', 'KickOut AlternateTake', 'Vocals Keys Proto', 'Dobro', 'Sleighbells', 'DRUMS  OH L M API', 'LeadVox', 'ElecGtrEbow', 'Paliteo', 'DrumsSansamp', 'Cymbal hit', 'ViolasB', 'Saxophones', 'Vocals Paul CU', 'DrumkitClose', 'Beat', 'LESLIE RIGHT   M', 'Cello M', 'ROOM AB    RIGHT', 'Diabara', 'SynthFX', 'PercChoirRibbons', 'Strings Ensemble', 'Vocals Vocal M', 'DoubleBassesB', 'SpotMic Sopranos', 'MainPair MSDecoded', 'Conga Hi', 'DrumsRioom', 'Vocals Adam Proto', 'Bass AlternatePart', 'SubBass', 'ElecGtrAltTake', 'NylonGtr', 'Drums Drum Shell U', 'IntroClose', 'Kt. HH', 'Bombek', 'Backing Vox A (Korby KAT C )', 'DoubleBasses', 'YAMAHA', 'Cabasa', 'GUITAR   AR    BAE', 'Bass bip', 'BackingVos', 'DrumMic', 'KickBack', 'SnareSFX', 'ACOUSTIC DI', 'BassAmpRoom', 'Bassoon', 'LeadVoxc', 'SpotMic Altos', 'CymbalFX', 'Mandolin Mic M', 'TrumpetSamples', 'DRUM TOMS  M SH API', 'VocoderFX', 'Tambourine AlternateTake', 'Drums Snare Bot M', 'Lead Vox', 'BassDIPedals', 'Cellos', 'Mellotron', 'DOBRO AR DAKING DISTRESSOR.R', 'LESLIE LEFT   M', 'Whisper', 'PianoSpot', 'SD DRUMS SNARE M SH API', 'Knocking', 'ElecGtrb Amb', 'GtrMic', 'TimpaniRolls', 'Drums Over Head ELA M', 'HarpHarmonics', 'SaxMic PeerArray', 'LyricalOctave', 'ELE Guitar Proto', 'AcousticGtr RemixEdit', 'Vocals Brian Proto', 'SampleSFX', 'Pianos', 'Sidestick', 'Synth', 'Kick', 'MANDOLIN AK VINTECH  LAA', 'DrumsKick', 'CHORUS VOCAL   U   BAE', 'ViolasA', 'SnareOD Room', 'Beep', 'GtrcAmp', 'Keys Juno PDI', 'KickSnare', 'Timbales', 'RhodesFX', 'Vocals Josh M', 'Cellos MicPair', 'Kick LiveRoom', 'Gtr VsDown', 'Psaltery', 'ROOM LEFT   M', 'Snaps', 'VoxMid', 'BackingVoxb Singer', 'Keys  Passive DI', 'Keys Piano  M', 'PercChoirMains', 'LeadVoxBr', 'VoxIntro', 'Bass TDA', 'Sticks', 'AcousticGtrMic', 'KickRoom', 'BackVox', 'DjembeFX', 'Bass Amp (prototype)', 'VoxWhisper', 'Drumkit Cymbal', 'DnareDown', 'OUTRO ALTO E SSLE', 'Horns Sax Flute M', 'Soprano', 'Breathing', 'LeadVoxVsSFX', 'SopranoOD', 'DrumsSFX', 'OverheadsLayer', 'DRUM Hi Hats M', 'AcousticGtrMics', 'SAMPLER DI', 'KEYS RIGHT   DI   LaChappel', 'AcousticGtrDTReverse', 'SaxMic SpotMic', 'TomFX', 'PianoMicPair', 'LeadVoxDTMic', 'Theme', 'PIANO CLOSE  .R', 'Timpani', 'Drumkit DrumsSquashMic', 'BassAmp', 'DrumFills', 'PianoInsideMics', 'Breaks', 'Keys Passive DI', 'VOX BG CU NEVE LB CLB', 'ElecGtr', 'CymbalSamples', 'BR   DRUMS KICK M', 'Vocals Amy M', 'Fiddle M', 'Gtrb Mic', 'SnareUpMic', 'SD BASS AMP CU LACHAPELL', 'Gidamba', 'ElecGtrMic', ...
# Cluster 0: ['RIde', 'Ride', 'Drums Ride M', 'DRUM Ride M', 'Drums Ride ELA M']
# Cluster 1: ['Vocals Acoustic Guitar Proto', 'Acoustic Guitar ELA M', 'E GUITAR   M', 'Acoustic Guitar M', 'Acoustic Guitar Leslie Ela M', 'E GUITAR  M', 'Acoustic Guitar Guitar M', 'Guitar M', 'Vocals Guitar Proto', 'Acoustic Guitar Proto', 'Guitar', 'Acoustic Guitar Ela M', 'Acoustic Guitar Lead Ela M', 'Acoustic Guitar AR']
# Cluster 2: ['AC GUITAR', 'AC GUITAR CU', 'AC GUITAR AR']
# Cluster 3: ['VOX AC GUITAR C GRACE', 'VOX AC GUITAR M GRACE', 'AC GUITAR M GRACE']
# Cluster 4: ['DRUM Snare Top M SH', 'SNARE TOP M SH', 'DRUMS   SNARE   M SH', 'DRUM SNARE M SH API', 'DRUMS   Snare   M SH', 'SNARE M SH']
# Cluster 65: ['Mandolin Ela M', 'Mandolin DI', 'Mandolin']
# Cluster 5: ['Chamber Ar', 'CHAMBER', 'Chamber M', 'Drums Chamber  AR', 'Drums Chamber AR', 'Drums Chamber M']
# Cluster 18: ['Vocals Bass Proto', 'Vocals BG Bass  M', 'Vocals BG M', 'Vocals BG Keys M', 'Vocals BG Bass M', 'Vocals BG Bass Proto']
# Cluster 6: ['AH ALTO AK SSLE', 'AH ALTO E SSLE', 'AH DBL ALTO AK SSLE', 'AH DBL ALTO E SSLE']
# Cluster 7: ['Trumpet', 'Trumpet', 'Vocals Trumpet M']
# Cluster 35: ['DRUM Kick In M', 'KICK   U   API', 'DRUMS KICK M API', 'DRUM KICK M API', 'SD DRUMS KICK M API']
# Cluster 8: ['ELE Guitar Amp M', 'ELE Guitar AMP CU', 'ELE Guitar  Con CU', 'ELE Guitar  M', 'Ele Guitar Amp CU', 'ELE Guitar  Con AR', 'ELE Guitar Con AR', 'Ele Guitar Amp M', 'ELE Guitar Con CU', 'Vocals ELE Guitar M', 'ELE Guitar Con M', 'ELE Guitar M']
# Cluster 9: ['Drums Overhead L C', 'Drums Overhead U', 'Overhead', 'Drums Overhead CU', 'DRUMS   OVERHEAD LEFT   ELA M', 'Drums Overhead ELA M', 'Drums Overhead Ela M', 'Drums Overhead AR', 'Drums Overhead Ar', 'Drums Overhead R C', 'DRUMS   OVERHEAD RIGHT   ELA M', 'Drums Overhead ELA M', 'Drums Overhead M']
# Cluster 10: ['Drums Kick in M', 'Drums Kick Out CU', 'Drums Kick Out U', 'Drums Kick Out  CU', 'Drums Kick M', 'Drums Kick In M.', 'Drums Kick Out', 'Drums Kick', 'DRUMS   Kick Out   M', 'Drums Kick', 'Drums Kick out CU', 'Drums Kick Out Cu', 'DRUMS   KICK M', 'Drums Kick In M']
# Cluster 11: ['Vocals Lead Proto', 'Vocals Lead M', 'Vocals Lead M', 'Vocals Lead U', 'Vocals Lead CU', 'Vocals LEAD M']
# Cluster 12: ['AC GUITAR  CU SHADOWHILL.L', 'AC GUITAR  CU SHADOWHILL .R', 'AC GUITAR  CU SHADOWHILL .L', 'AC GUITAR  CU SHADOWHILL.R']
# Cluster 13: ['Tom', 'TOM', 'Drums Tom M', 'Tom']
# Cluster 14: ['VOX MANDOLIN M GRACE', 'VOX MANDOLIN  GRACE', 'MANDOLIN M GRACE']
# Cluster 15: ['BASS DI', 'BASS DI', 'Bass DI', 'BASS DI SSLE', 'BASS DI', 'Bass DI']
# Cluster 16: ['BASS MIC', 'Bass Mic', 'Bass Mic AK', 'Bass Mic M', 'Bass Mic Ak']
# Cluster 68: ['ElecGtrb Room', 'ElecGtrb DI', 'ElecGtrb']
# Cluster 17: ['ROOM A   AR    Chandler Germanium   Distressor', 'ROOM B   AR    Chandler Germanium   Distressor', 'ROOM D   AR    Chandler Germanium', 'ROOM C   AR    Chandler Germanium']
# Cluster 19: ['GROUP VOCALS    U   BAE', 'GROUP VOCALS    C   BAE', 'GROUP VOCALS   C   BAE']
# Cluster 56: ['BANJO DI', 'Banjo', 'Banjo CU']
# Cluster 20: ['ELE Guitar  Con AK', 'ELE Guitar Con Mic AK', 'ElE Guitar Con AK']
# Cluster 21: ['Drums Over TF', 'Drums Kick Out TF', 'Drums Over TF.']
# Cluster 22: ['Drums Overheads CU', 'DRUMS   Overheads   M.L', 'Drums Overheads M', 'Overheads', 'Overheads', 'Drums Overheads ELA M', 'Drums Overheads AR', 'Drums Overheads Ela M', 'DRUMS   Overheads   M.R']
# Cluster 23: ['Drums Hat Ela M', 'Drums HAT Ela M', 'Drums Hat M', 'Hat', 'Drums HAT  Ela M', 'Drums Hat ELA M', 'Drums Hat ELA M', 'Hat', 'Drums HAT M']
# Cluster 24: ['Drums Floor Tom CU', 'DRUMS   TOM    M SH', 'Drums Floor Tom M', 'TOM  M SH', 'Drums Floor Tom  M.', 'Drums Floor M', 'Drums Floor  M', 'Drums Floor M.', 'DRUMS   TOM   M SH', 'DRUMS   FLOOR TOM   M SH', 'Drums Floor Tom Proto']
# Cluster 25: ['VOX    M', 'VOX  M', 'VOX   M', 'Vox', 'VOX', 'VOX']
# Cluster 26: ['ORGAN VOX ALTO U SSLE', 'ORGAN VOX ALTO CU SSLE', 'ORGAN DBL VOX ALTO U SSLE', 'ORGAN DBL VOX ALTO CU SSLE']
# Cluster 41: ['Percussion Overhead CU', 'Percussion Overhead M', 'Percussion Overhead AR']
# Cluster 27: ['Drums Snare M.', 'Drums Side Snare M', 'Drums Snare bottom M', 'Drums Snare', 'Drums Snare Top M', 'Drums Snare top M', 'Drums Snare M', 'Snare', 'Drums Snare Bottom M', 'SNARE BOTTOM M', 'Snare', 'Snare']
# Cluster 28: ['ORGAN VOX TENOR AK SSLE', 'ORGAN DBL VOX TENOR E SSLE', 'ORGAN VOX TENOR E SSLE', 'ORGAN DBL VOX TENOR AK SSLE']
# Cluster 29: ['Horns Bone Ela M', 'Horns Bone Proto', 'Horns Bone M', 'Horns Bone AR', 'Horns Bone ELA M']
# Cluster 30: ['Keys Leslie M', 'Keys Leslie M.', 'Keys Leslie Top M', 'Keys Leslie Bottom M']
# Cluster 31: ['GTR CON', 'GTR  M', 'Gtr']
# Cluster 32: ['VOX LD CU', 'VOX LD U', 'VOX LD AR', 'VOX LD E']
# Cluster 33: ['Horns Trumpet Ela M', 'Horns Trumpet ELA M', 'Horns Trumpet  ELA M', 'Horns Trumpet M']
# Cluster 34: ['ORGAN LESLIE TOP M SH.L', 'LESLIE TOP M SH', 'ORGAN LESLIE BOTTOM M', 'ORGAN LESLIE TOP M SH.R']
# Cluster 36: ['HI HAT M', 'DRUMS   HI HAT   ELA M', 'HI HAT   ELA M    API', 'NBATG   Hi Hat  ELA M', 'Hi Hat', 'NBATG   OH Hi Hat   ELA M']
# Cluster 37: ['Drums Rack Tom M.', 'Drums Rack Tom  M.', 'Drums Rack CU', 'Drums Rack Tom Proto', 'Drums Rack Tom M', 'Drums Rack  M', 'Drums Rack M']
# Cluster 38: ['Percussion', 'Percussion M', 'Percussion  M']
# Cluster 39: ['Bass M', 'BASS   M', 'Bass', 'BASS U']
# Cluster 55: ['Horns Sax  AK', 'Horns Sax M', 'Horns Sax Proto']
# Cluster 40: ['ElE Guitar Dyn M', 'ELE Guitar Dyn Mic M', 'ELE Guitar  Dyn M', 'ELE Guitar Dyn M']
# Cluster 42: ['Hihat', 'HiHat', 'HiHat']
# Cluster 51: ['ElecGtrc Mic', 'ElecGtrc', 'ElecGtrc DI']
# Cluster 43: ['Bass Amp M.', 'Bass Amp U', 'Bass Amp', 'BASS AMP CU API', 'Bass Amp AK', 'Bass Amp CU', 'Bass Amp M']
# Cluster 44: ['SNARE TOP   M   API', 'SNARE BOTTOM   M   API', 'DRUMS SNARE M API']
# Cluster 45: ['Keys  Active DI', 'Keys Active DI', 'NORD R DI', 'NORD L DI', 'Keys Organ Active DI', 'Keys Nord DI', 'Keys Nord  Active DI', 'NORD']
# Cluster 46: ['UKULELE E SSLE', 'Ukulele', 'UKULELE  SSLE']
# Cluster 66: ['KEY RIGHT DI', 'KEY LEFT DI', 'KEY DI']
# Cluster 47: ['DJEMBE BOTTOM  SSLE', 'DJEMBE TOP U SSLE', 'Djembe', 'DJEMBE TOP AR SSLE']
# Cluster 48: ['Room ELA M E', 'Room L Ela M', 'Room ELA M', 'Room R Ela M']
# Cluster 49: ['E GUITAR M CHANDLER TG CHANNEL', 'E GUITAR AR CHANDLER TG CHANNEL', 'E GUITAR CU CHANDLER TG CHANNEL']
# Cluster 50: ['ElecGtrd DI', 'ElecGtrd', 'ElecGtrD']
# Cluster 52: ['Keys DI', 'KEYS DI.R', 'Keys  DI', 'KEYS DI.L']
# Cluster 53: ['Trombone', 'TROMBONE M API', 'Trombone']
# Cluster 54: ['DRUM OH AK SSL DUALITY.R', 'DRUM OH C SSL DUALITY.L', 'DRUM OH C SSL DUALITY.R', 'DRUM OH AK SSL DUALITY.L']
# Cluster 57: ['Keys Hammond M', 'Keys Hammond Bottom CU', 'Hammond', 'Keys Hammond Top M']
# Cluster 58: ['Vox SFX', 'SfX', 'SFX']
# Cluster 59: ['PIANO ROOM AR .R', 'PIANO ROOM AR .L', 'Room Piano U']
# Cluster 60: ['LD VOX ALTO A AC SSLE', 'LD VOX ALTO B E SSLE', 'LD VOX ALTO B AK SSLE', 'LD VOX ALTO A U SSLE', 'LD VOX ALTO A CU SSLE', 'LD VOX ALTO B  SSLE']
# Cluster 61: ['ROOM A   Beyer Dynamic    Neve', 'ROOM B   Beyer Dynamic    Neve', 'ROOM D   Beyer Dynamic    Neve', 'ROOM C   Beyer Dynamic    Neve']
# Cluster 62: ['Dun Dun Set TF', 'Dun Dun Extra  M', 'Dun Dun   M', 'Dun Dun  M', 'Dun Dun  M']
# Cluster 63: ['LD VOX SOPRANO A  SSLE', 'LD VOX SOPRANO B U SSLE', 'LD VOX SOPRANO A AK SSLE', 'LD VOX SOPRANO B AC SSLE', 'LD VOX SOPRANO A E SSLE', 'LD VOX SOPRANO B CU SSLE']
# Cluster 64: ['AH SOPRANO U SSLE', 'AH DBL SOPRANO U SSLE', 'AH DBL SOPRANO CU SSLE', 'AH SOPRANO CU SSLE']
# Cluster 67: ['Drums Kick Out Proto', 'Drums Kick Out Proto', 'Drums Kick Out  Proto']
# Cluster 69: ['Room U', 'Room', 'Room M']

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
# Step 5: Apply Agglomerative Hierarchical Clustering
agg_clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=0.5)  # No predefined number of clusters
labels = agg_clustering.fit_predict(embeddings_normalized)
print("Labels: ", labels)
# Out:
# Labels:  [ 905   28  133 ... 1014  411  205]

# %%
# calculate the depth of the dendrogram
Z = sch.linkage(embeddings_normalized, method='ward')
depth = 3
# Step 6: Group names by cluster labels
clusters = {}
for idx, label in enumerate(labels):
    if label not in clusters:
        clusters[label] = []
    clusters[label].append(names[idx])
print("Clusters: ", clusters)
# Out:
# Clusters:  {905: ['Horn'], 28: ['CymbalsOD', 'CymbalsOD Overheads'], 133: ['DrumsSnareUp', 'DrumsSnareDown'], 162: ['BASS CAB   CU  copperhead   BAE', 'GUITAR   CU  copperhead   BAE'], 313: ['Kick SFX', 'KickSFX'], 567: ['RIde', 'Ride'], 215: ['SaxophoneCloseMic', 'SaxophoneFarMic', 'BassCloseMic'], 929: ['ElecPianoSFX'], 763: ['BassFX'], 93: ['HiHatRide', 'Loop HiHat'], 77: ['Vocals Erica M', 'Vocals Amy M', 'Vocals Leslie  Ela M'], 274: ['CymbalSwells', 'CymbalSwell'], 44: ['Vocals Acoustic Guitar Proto', 'Vocals Bass Proto', 'Vocals Keys Proto', 'Vocals Banjo Proto', 'Vocals Guitar Proto', 'Acoustic Guitar Proto'], 337: ['AC GUITAR', 'AcGuitar'], 1010: ['BackingVoxDT'], 354: ['DRUM OH AR LANGEVIN.L', 'DRUM OH AR LANGEVIN.R'], 243: ['LESLIE BOTTOM M', 'Keys Leslie Bottom M'], 443: ['ElecGtra Mic', 'ElecGtrb Mic', 'ElecGtrc Mic'], 1027: ['DrumsTom'], 228: ['Saxophone', 'BassClarinet', 'TromboneBass', 'BassTrombone'], 813: ['PercLoop'], 642: ['VOX AC GUITAR C GRACE', 'VOX AC GUITAR M GRACE', 'AC GUITAR M GRACE'], 777: ['LeadVoxAccents'], 1004: ['Vocals Bone M'], 273: ['SFXLoop', 'MIDIStrings', 'MIDIViolin', 'Sleighbells', 'Paliteo', 'Diabara', 'Bombek', 'Cabasa', 'Sidestick', 'Gidamba', 'Pizz', 'Synthd', 'Rainstick', 'MIDITrombone', 'Guitalele', 'Cimbassi', 'Guasa', 'Glup', 'Hihat', 'Rototom', 'Recordier', 'SFXIntro', 'Clav', 'Pandero', 'MIDIViolas', 'Snarea', 'Flugelhorns', 'EGutiar    (Earthworks SR)', 'MIDIGuitar', 'Gtrb', 'Vibrophone', 'Bassc', 'MIDISax', 'SFXWet', 'Snarec', 'SFXWolf', 'Vibraslap', 'Snaree', 'MIDITrombones', 'Synthb', 'Heartbeart', 'Kicksnare', 'EGuitar    (Palmer PDI)', 'Synthc', 'Subbass', 'Llenties', 'MIDITrumpet', 'Doublebasses', 'Tamb', 'SFXLaugh', 'HHat', 'Cunono', '', 'Snareb', 'Llamador', 'MIDIGtr', 'Srtings', 'Syntha', 'Cachapas', 'Euphoniiums', 'Leadvox', 'SFXHit', 'Clonk', 'Gtra', 'Bassb', 'SFXDry', 'Guache', 'MIDIChoir'], 917: ['LeadVoxMic'], 932: ['Drumkit RoomMono'], 32: ['AcGtrDI', 'GtrDI'], 599: ['ElecGtra Close'], 439: ['RoomMono', 'MonoRoom', 'Room Mono'], 1051: ['Bulldozer'], 989: ['BassHi'], 879: ['SampleBrass'], 2: ['DoubleBass', 'Spot Bass', 'DoubleBassSamples'], 968: ['Hat SFX'], 469: ['ROOM STEREO L   C w TFUNK CK   Neve', 'ROOM STEREO R   C w TFUNK CK   Neve'], 990: ['GlassBell'], 925: ['Clavinet'], 356: ['DRUM Snare Top M SH', 'SNARE TOP M SH'], 33: ['GUITAR AMP    M', 'Harp Amp M', 'Bass Amp M'], 714: ['BackingVoxa', 'BackingVoxd', 'BackingVoxb', 'BackingVoxe', 'BackingVoxf', 'BackingVoxc'], 880: ['LeadVoxTapeEffect'], 952: ['ReversePiano'], 206: ['BackingVoxBr', 'BackingVoxCh'], 188: ['DrumsSideR', 'DrumsSideL'], 906: ['FloorTom'], 582: ['OfficeAmbience'], 597: ['BEATBOX ALTO B AK SSLE'], 1000: ['LeadVox AltTake'], 534: ['BASS   DI    API', 'BASS DI API'], 56: ['Vocals BGV M', 'Vocals Vocal M', 'Guitar M', 'Vocals Trumpet M', 'Vocals Drums M', 'Vocals  M', 'Vocals Bass M'], 580: ['VoxSFX', 'Vox SFX'], 392: ['PIANO AK LANGEVIN.L', 'PIANO AK LANGEVIN.R'], 987: ['UkeleleMic'], 716: ['Loops'], 13: ['ViolaSamples', 'CelloSamples', 'TrumpetSamples', 'ViolinSamples'], 104: ['VoxGuitar', 'VoxBanjo'], 1058: ['VOX BG U'], 51: ['LeadVoxCha', 'LeadVoxLo'], 372: ['LeadVoxClose', 'LeadVoxFar'], 944: ['HornsDT'], 76: ['RoomLoFi', 'DrumsRoomLoFi'], 306: ['BassPedals', 'BassPedal'], 52: ['Mandolin Ela M', 'Aco Guitar ELA M'], 717: ['Chamber Ar'], 540: ['Acoustic Guitar ELA M', 'Acoustic Guitar Leslie Ela M', 'Acoustic Guitar Ela M', 'Acoustic Guitar Lead Ela M'], 997: ['RunningAsiza'], 449: ['LeadVoxVs', 'LeadVoxVsDT'], 80: ['NBATG   acoustic guitar DI', 'ACOUSTIC DI', 'Acoustic Guitar Active DI'], 950: ['Clicks'], 37: ['StringsPizz', 'Strings', 'StringsPizzicato'], 728: ['BassAlt'], 507: ['Cowbell', 'Cowbell'], 488: ['AH ALTO AK SSLE', 'AH DBL ALTO AK SSLE'], 826: ['Sax OD'], 640: ['Trumpet', 'Trumpet'], 223: ['DRUM Kick In M', 'Drums Kick in M', 'DRUMS   Kick In   M SH', 'Drums Kick In M'], 804: ['OverheadsIntro'], 451: ['ELE Guitar Amp M', 'Ele Guitar Amp M'], 450: ['DRUM RACK TOM M SSL DUALI ...

# %%
# Step 6: Generate a dendrogram for hierarchical clustering
# This shows the hierarchical structure
plt.figure(figsize=(100, 30))
sch.dendrogram(sch.linkage(embeddings_normalized, method='ward'))
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()

# Step 7: Dimensionality Reduction (PCA) for visualization
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings_normalized)

# Step 8: Plot interactive clusters using Plotly
df = pd.DataFrame(pca_result, columns=["PC1", "PC2"])
df['Cluster'] = labels
df['Name'] = names

# Plot using Plotly Express
fig = px.scatter(df, x="PC1", y="PC2", color='Cluster', text='Name', title="Hierarchical Clustering of Names")
fig.update_traces(textposition='top center')

# Show the plot
fig.show()

# %%
print(names)
# Out:
# ['Horn', 'CymbalsOD', 'DrumsSnareUp', 'BASS CAB   CU  copperhead   BAE', 'Kick SFX', 'RIde', 'SaxophoneCloseMic', 'ElecPianoSFX', 'BassFX', 'HiHatRide', 'Vocals Erica M', 'CymbalSwells', 'Vocals Acoustic Guitar Proto', 'AC GUITAR', 'BackingVoxDT', 'DRUM OH AR LANGEVIN.L', 'LESLIE BOTTOM M', 'ElecGtra Mic', 'DrumsTom', 'Saxophone', 'PercLoop', 'VOX AC GUITAR C GRACE', 'LeadVoxAccents', 'Vocals Bone M', 'SFXLoop', 'LeadVoxMic', 'Drumkit RoomMono', 'BassClarinet', 'AcGtrDI', 'ElecGtra Close', 'RoomMono', 'Bulldozer', 'BassHi', 'SampleBrass', 'DoubleBass', 'Hat SFX', 'ROOM STEREO L   C w TFUNK CK   Neve', 'GlassBell', 'Clavinet', 'MIDIStrings', 'DRUM Snare Top M SH', 'GUITAR AMP    M', 'BackingVoxa', 'LeadVoxTapeEffect', 'ReversePiano', 'BackingVoxBr', 'DrumsSideR', 'FloorTom', 'OfficeAmbience', 'BEATBOX ALTO B AK SSLE', 'LeadVox AltTake', 'BASS   DI    API', 'Vocals BGV M', 'VoxSFX', 'PIANO AK LANGEVIN.L', 'UkeleleMic', 'Loops', 'ViolaSamples', 'VoxGuitar', 'VOX BG U', 'LeadVoxCha', 'LeadVoxClose', 'HornsDT', 'RoomLoFi', 'BassPedals', 'Mandolin Ela M', 'Chamber Ar', 'Acoustic Guitar ELA M', 'RunningAsiza', 'LeadVoxVs', 'Vocals Bass Proto', 'NBATG   acoustic guitar DI', 'Clicks', 'StringsPizz', 'MIDIViolin', 'BassAlt', 'Cowbell', 'AH ALTO AK SSLE', 'Sax OD', 'Trumpet', 'DRUM Kick In M', 'CelloSamples', 'OverheadsIntro', 'ELE Guitar Amp M', 'DRUM RACK TOM M SSL DUALITY', 'ELE Guitar AMP CU', 'Lead Vox B (AKG )', 'Rhythm Gtr', 'ElecGtrLead', 'Bass AlternateTake', 'DRUM OVERHEAD STEREO R   AR    Neve', 'Paul Amp M', 'Drumkit OverheadMono', 'Strings Violin Active DI', 'Drums Overhead L C', 'AcGtrReampFar', 'Drums Kick in M', 'Idiophone', 'LeadVoxVsDT', 'ElecGtrDry', 'Drums Kick Out CU', 'TreeChopFall', 'Vocals Tim CU', 'Vocals Lead Proto', 'E GUITAR   M', 'CymbalWash', 'AC GUITAR  CU SHADOWHILL.L', 'DRUMS   Kick In   M SH', 'Tom', 'VOX MANDOLIN M GRACE', 'CellosAndBassesSpiccato', 'SaxMic', 'DrumKit', 'DrumsBreak', 'KickOut AlternateTake', 'Vocals Keys Proto', 'Drums Kick Out U', 'Dobro', 'Sleighbells', 'BASS DI', 'DRUMS  OH L M API', 'LeadVox', 'ElecGtrEbow', 'BASS MIC', 'Paliteo', 'Bass Mic', 'DrumsSansamp', 'Cymbal hit', 'ViolasB', 'Saxophones', 'TOM', 'Vocals Paul CU', 'ElecGtrb Room', 'ROOM A   AR    Chandler Germanium   Distressor', 'DrumkitClose', 'Beat', 'Vocals BG Bass  M', 'LESLIE RIGHT   M', 'GROUP VOCALS    U   BAE', 'Cello M', 'ROOM AB    RIGHT', 'Diabara', 'SynthFX', 'PercChoirRibbons', 'BANJO DI', 'Vocals Lead M', 'Strings Ensemble', 'Vocals Vocal M', 'ELE Guitar  Con AK', 'DoubleBassesB', 'Drums Over TF', 'SpotMic Sopranos', 'MainPair MSDecoded', 'Conga Hi', 'DrumsRioom', 'Vocals Adam Proto', 'Bass AlternatePart', 'SubBass', 'ElecGtrAltTake', 'NylonGtr', 'Drums Overheads CU', 'Drums Drum Shell U', 'IntroClose', 'Kt. HH', 'Bombek', 'Backing Vox A (Korby KAT C )', 'DoubleBasses', 'YAMAHA', 'Cabasa', 'Drums Kick Out TF', 'GUITAR   AR    BAE', 'Bass bip', 'BackingVos', 'DrumMic', 'KickBack', 'SnareSFX', 'ACOUSTIC DI', 'BassAmpRoom', 'Acoustic Guitar M', 'Bassoon', 'LeadVoxc', 'SpotMic Altos', 'CymbalFX', 'Mandolin Mic M', 'TrumpetSamples', 'DRUM TOMS  M SH API', 'VocoderFX', 'Tambourine AlternateTake', 'Drums Snare Bot M', 'Lead Vox', 'BassDIPedals', 'Cellos', 'Mellotron', 'Drums Hat Ela M', 'DOBRO AR DAKING DISTRESSOR.R', 'LESLIE LEFT   M', 'Whisper', 'PianoSpot', 'SD DRUMS SNARE M SH API', 'Drums Floor Tom CU', 'Knocking', 'ElecGtrb Amb', 'GtrMic', 'TimpaniRolls', 'VOX    M', 'Drums Over Head ELA M', 'HarpHarmonics', 'SaxMic PeerArray', 'LyricalOctave', 'ELE Guitar Proto', 'AcousticGtr RemixEdit', 'Vocals Brian Proto', 'SampleSFX', 'Pianos', 'Sidestick', 'Synth', 'Kick', 'MANDOLIN AK VINTECH  LAA', 'DrumsKick', 'CHORUS VOCAL   U   BAE', 'ViolasA', 'SnareOD Room', 'Beep', 'GtrcAmp', 'Keys Juno PDI', 'KickSnare', 'Drums Kick Out  CU', 'Timbales', 'RhodesFX', 'Vocals Josh M', 'ORGAN VOX ALTO U SSLE', 'Cellos MicPair', 'Drums HAT Ela M', 'Kick LiveRoom', 'Gtr VsDown', 'Psaltery', 'ROOM LEFT   M', 'Snaps', 'VoxMid', 'Percussi ...

# %%
# Lowercase all names
instrument_groups = {}
for idx, name in enumerate(names):
    names[idx] = name.lower()

    if "kick" in name:
        instrument_groups.setdefault("kick", []).append(name)
    elif "snare" in name:
        instrument_groups.setdefault("snare", []).append(name)
    elif "hihat" in name:
        instrument_groups.setdefault("hihat", []).append(name)
    elif "tom" in name:
        instrument_groups.setdefault("tom", []).append(name)
    elif "cymbal" in name:
        instrument_groups.setdefault("cymbal", []).append(name)
    elif any(keyword in name for keyword in ["perc", "shaker", "kalimba", "clap", "snap", "crash", "hi", "hat", "djembe","cowbell", "conga","glockenspiel", "timpani","congo", "ride", "beat", "perc", "overhead", "beatbox", "tambourine", "triangle", "maraca", "bongo", "cabasa", "guiro", "woodblock", "clave", "castanet", "agogo", "whistle", "bell", "chime", "gong", "tambourine"]):
        instrument_groups.setdefault("percussion", []).append(name)
    elif "drum" in name:
        instrument_groups.setdefault("drum", []).append(name)
    elif "bass" in name:
        instrument_groups.setdefault("bass", []).append(name)
    elif "synth" in name:
        instrument_groups.setdefault("synth", []).append(name)
    elif any(keyword in name for keyword in ["piano", "keys", "clavinet", "rhodes", "accordion"]):
        instrument_groups.setdefault("keys", []).append(name)
    elif "room" in name:
        instrument_groups.setdefault("room", []).append(name)
    elif "organ" in name:
        instrument_groups.setdefault("organ", []).append(name)
    elif any(keyword in name for keyword in ["brass", "trumpet", "trombone", "horn", "bagpipe","tuba", "euphonium"]):
        instrument_groups.setdefault("brass", []).append(name)
    elif any(keyword in name for keyword in ["woodwind", "flute", "clarinet", "oboe", "saxophone", "sax", "bassoon", "alto", "soprano"]):
        instrument_groups.setdefault("woodwind", []).append(name)
    elif any(keyword in name for keyword in ["vocal", "choir", "vox", "backing"]):
        instrument_groups.setdefault("vocal", []).append(name)
    elif any(keyword in name for keyword in ["string", "violin", "cello", "viola"]):
        instrument_groups.setdefault("string", []).append(name)
    elif "fx" in name:
        instrument_groups.setdefault("fx", []).append(name)
    elif any(keyword in name for keyword in ["guitar", "gtr","ukulele", "ukelele" "banjo", "fiddle", "mandolin"]):
        instrument_groups.setdefault("guitar", []).append(name)
    else:
     
        instrument_groups.setdefault("other", []).append(name)

# Print instrument groups and their counts
for key, value in instrument_groups.items():
    print(key, len(value))
    print(value)
    print("\n\n")
# Out:
# brass 58
# ['horn', 'samplebrass', 'hornsdt', 'trumpet', 'trumpetsamples', 'horns sax flute m', 'horns bone ela m', 'bagpipedrones', 'trumpet', 'horns trumpet ela m', 'horn trumpet ela m', 'miditrombone', 'frenchhorn', 'horns sax  ak', 'brassandreeds', 'horns bone proto', 'frenchhornsamples', 'trombones', 'flugelhorns', 'horns trumpet msh', 'trombone', 'tubas', 'brass', 'horns sax m', 'miditrombones', 'vocals bg trumpet m', 'horns bari m', 'trumpets', 'trombone a   ar    neve', 'trombone m api', 'miditrumpet', 'horns bone m', 'brassstaccatolo', 'horns bone wet m', 'brasscrescendo', 'horns tenor ar', 'horns sousaphone m', 'horns trumpet ela m', 'horns trumpet  ela m', 'vocals trumpet m', 'trumpet a   ar    neve', 'horns bone ar', 'frenchhorns', 'horns bone ela m', 'sd vox trumpet m', 'trombone b   ar    neve', 'horn tenor m', 'horns bari ar', 'tuba', 'bagpipechanter', 'trumpet b   ar    neve', 'horns sax proto', 'trumpet m api', 'trombone', 'horns tenor m', 'horns trumpet m', 'brassdrop', 'horns']
#
#
#
# cymbal 30
# ['cymbalsod', 'cymbalswells', 'cymbalwash', 'cymbal hit', 'cymbalfx', 'drumkit cymbal', 'cymbalsamples', 'cymbalrolls', 'reverse cymbal', 'reversecymbalfx', 'reversecymbals', 'cymbal', 'fingercymbals remixaddition', 'chinacymbal', 'reversecymbal', 'cymbalsfx', 'overheads cymbalsonly', 'drumsroommono cymbalsonly', 'cymbalsod room', 'room cymbalsonly', 'cymbalswell remixaddition', 'cymbalroll', 'cymbalswell', 'reversed cymbal', 'drumsroomstereo cymbalsonly', 'drumsamples cymbals', 'cymbalsod overheads', 'cymbalsample', 'revcymbal', 'cymbals']
#
#
#
# snare 85
# ['drumssnareup', 'drum snare top m sh', 'snaresfx', 'drums snare bot m', 'sd drums snare m sh api', 'snareod room', 'drums snare m.', 'drums side snare m', 'snareupmic', 'snarerolls', 'drumkit snaremic', 'snare top m sh', 'snaresquash', 'snareroom', 'nbatg   snare   m', 'snarefills', 'drums snare bottom m', 'snarerimod overheads', 'snare drum', 'snare sfx', 'snareamb', 'drums   snare   m sh', 'snare top   m   api', 'snareod snaredown', 'snaresample', 'drumsamples snare', 'drumkit snaredown', 'snarerimod room', 'snare bottom   m   api', 'drum snare m sh api', 'snarea', 'br   drums snare m chrome', 'drums snare', 'snareod trashmic', 'snareod', 'drums aux snare m.', 'snare liveroom', 'snarering', 'snared', 'snareup', 'snaresampleroom', 'snaredown alternatetake', 'snarec', 'snaree', 'snaresub', 'drum snare bottom m', 'drums snare top m', 'drum snare b m hardey m dbx', 'reversedsnare', 'reversesnare', 'snarerimod', 'snaretrigger', 'snareside', 'snareover', 'drums snare top m', 'drums snare m', 'snare', 'snaredtdown', 'drums snare m api', 'drums snare bottom m', 'drumssnaredown', 'drumkit snare', 'snareod snareup', 'drums   snare   m sh', 'drumkit snareup', 'snarecymbals', 'drum snare b m ssl duality', 'snareandcymbal', 'snareb', 'snaredtup', 'snareunder', 'snaremic', 'snare bottom m', 'snaredrum', 'snaredown', 'snare', 'tomsnaresamples', 'snare', 'drum snare t m avalon  distressor', 'snarefx', 'drum snare t m ssl duality', 'snaredelay', 'drumssnare', 'snareup alternatetake', 'snare m sh']
#
#
#
# bass 118
# ['bass cab   cu  copperhead   bae', 'bassfx', 'bassclarinet', 'doublebass', 'bass   di    api', 'basspedals', 'vocals bass proto', 'bassalt', 'bass alternatetake', 'cellosandbassesspiccato', 'bass di', 'bass mic', 'bass mic', 'vocals bg bass  m', 'doublebassesb', 'bass alternatepart', 'subbass', 'doublebasses', 'bass bip', 'bassamproom', 'bassoon', 'bassdipedals', 'bass tda', 'bass amp (prototype)', 'bassamp', 'sd bass amp cu lachapell', 'bassdi', 'doublebasses remixaddition', 'bassdist', 'bassmic peerarray', 'vox bass m', 'cimbassi', 'bass m', 'bass   m', 'upright bass   di   neve', 'bassmic liveroom', 'nbatg   bass guitar di', 'bass di', 'bass amp m.', 'bass di api', 'bass ak daking clb', 'basssub', 'bass di', 'bass active di', 'bassguitaramp', 'bass mic ak', 'bassoons', 'bassmic', 'bassa', 'bassod', 'basssynth', 'bassguitardi', 'basssubsynth remixaddition', 'bassc', 'bass', 'bass amp u', 'bassoverdrive', 'bass amp cu lachapelle', 'bassswell', 'bassslideamp', 'bass active di.', 'bassflutes', 'bass di ssle', 'bass synth di ssle', 'bassmidi', 'subbass', 'sd bass di lachapell', 'bassgtrdi', 'bass mic m', 'bass amp', 'sub bass', 'br   bass m blue', 'doublebasses', 'pizzbass', 'oboebassoon', 'basslayer', 'bass amp cu api', 'bassbi', 'basssfx', 'bassgtramp', 'bass di', 'contrabassoon', 'bassguitar', 'bassslidedi', 'bassampdist', 'doublebassesa', 'basslo', 'synthbass', 'bass amp ak', 'spot bass', 'vocals bg bass m', 'bass amp cu', 'doublebasssamples', 'basstrombones', 'bass u', 'bass mic ak', 'vocals bg bass proto', 'basssansamp', 'bassampmic', 'trombonebass', 'upright bass   ela m    neve', 'cellobasslo mic', 'basses', 'bass cab   u   bae', 'vox bass m', 'bassb', 'bassclosemic', 'bassfuzz', 'spotmic basses', 'vocals bass m', 'bassmic spotmic', 'bassdi liveroom', 'bass amp m', 'basstrombone', 'basspedal', 'bass amp tf', 'bass di', 'bass di tda']
#
#
#
# kick 81
# ['kick sfx', 'drum kick in m', 'drums kick in m', 'drums kick out cu', 'drums   kick in   m sh', 'kickout alternatetake', 'drums kick out u', 'drums kick out tf', 'kickback', 'kick', 'drumskick', 'kicksnare', 'drums kick out  cu', 'kick liveroom', 'kickroom', 'br   drums kick m', 'drums kick m', 'kick   u   api', 'kickinmic', 'drums kick in m.', 'drum kick i beta  hardley m a', 'drums kick out', 'kickbatter', 'kick   m (stock version)   api', 'drum kick i m ssl duality', 'kick   u   neve', 'drums kick m api', 'kickpunch', 'kickfront', 'kickfar', 'drums kick', 'drum kick m api', 'kickmain', 'drums kick out ak', 'kickout', 'nbatg   kick   m', 'kickodmic', 'drum kick out (prototype)', 'drums   kick out   m', 'kicksampleroom', 'drums kick', 'drumskickout', 'drums kick out cu', 'drum kick i m neve lb audio arts eq distressor', 'kickamb', 'kickmic', 'kicksnare', 'kickside', 'drumskickin', 'kicksnarefx', 'sd drums kick m api', 'drums kick out cu', 'kickbass', 'kicklayer', 'kicksub', 'kicktop', 'drum kick o yamaha sub hardey m dbx a', 'drums kick out proto', 'kick   m (new instrument prototype design)   api', 'drumkit kickin', 'kickfx', 'kickin', 'drumkit kickbeater', 'drums kick out proto', 'drum kick o u ssl duality', 'drums kick out ak', 'kickin alternatetake', 'kicksfx', 'drumkit kickout', 'kickclose', 'kicktrigger', 'kick m', 'drums kick out  proto', 'kickbeater', 'drums   kick m', 'drumkit kicksub', 'drums kick in m', 'drumkit kick', 'kicksample', 'kick   u   lachappel tfunk v  series tube pre', 'kickssmple']
#
#
#
# percussion 221
# ['ride', 'percloop', 'basshi', 'hat sfx', 'glassbell', 'beatbox alto b ak ssle', 'cowbell', 'overheadsintro', 'drum overhead stereo r   ar    neve', 'drumkit overheadmono', 'drums overhead l c', 'ac guitar  cu shadowhill.l', 'sleighbells', 'beat', 'percchoirribbons', 'conga hi', 'drums overheads cu', 'cabasa', 'tambourine alternatetake', 'drums hat ela m', 'whisper', 'timpanirolls', 'drums hat ela m', 'snaps', 'percussion overhead cu', 'percchoirmains', 'djembefx', 'voxwhisper', 'breathing', 'overheadslayer', 'drum hi hats m', 'timpani', 'glockenspiel', 'pianohi', 'overheadstriggers', 'electropercussion', 'shakerdt', 'perc shaker.', 'congamic', 'drums overhead u', 'leadvoxhi', 'hatopen', 'outrohit', 'hatclosed', 'percussion tim m', 'hi hat m', 'synthbells', 'overhead r m fet', 'claves', 'percussion', 'tubularbells', 'overheadsmono', 'overhead', 'drum overhead oh right cu grace', 'drums   hi hat   ela m', 'cowbell', 'drums overhead cu', 'highwayambience', 'drums   overheads   m.l', 'hi hat m fet', 'gong', 'percussion overhead m', 'shakers', 'drummachine', 'spot highstrings', 'conga monooverhead', 'guiro', 'clap', 'drumkit ride', 'conga a m sh api', 'tambourineamb', 'djembe  m sh', 'conga b m sh api', 'whistle', 'ac guitar  cu shadowhill .r', 'gongswell remixaddition', 'bongo', 'overheads rideonly', 'percussion mfet api', 'drums   overhead left   ela m', 'drum overhead stereo l   ar    neve', 'low whistle', 'drums overheads m', 'triangle', 'overheads m fet.l', 'overhead l m fet', 'overheadsstereo', 'percussion m', 'tambourine', 'overheads', 'ride', 'overheads', 'beatbox tenor ac ssle', 'chimes sfx', 'drums overhead ela m', 'hammondhi', 'clapsample', 'djembe top u ssle', 'tapehiss', 'drums overheads ela m', 'bells', 'ride   ela m    bae', 'drums ride m', 'shakermono', 'tambourinesample', 'asizabreathing', 'whistlemic', 'percchoiroutrigs', 'percussion overhead ar', 'percussionloop remixaddition', 'overheadstereo', 'drumkit overhead', 'sd drums hat m api', 'nbatg   oh ride   ela m', 'drums overhead ela m', 'drums overhead ar', 'drums hat m', 'whisperdt', 'hammondmichi', 'orchestrahit', 'hat', 'claps sfx', 'chimes', 'drums hat  ela m', 'drums overhead ar', 'percsolo closemic', 'claps', 'keys whirly amp m', 'congas', 'drums overheads ar', 'maracas', 'drums overheads ela m', 'percussionsfx', 'handbells', 'handclaps', 'malaysiandjembe', 'hi hat   ela m    api', 'percussion conga m', 'beatbox group omni  ssle', 'shakerstereo', 'bellpiano', 'bell sample', 'drumkitoverheads', 'drumkit overheadsstereo', 'conga', 'percussion bongo m', 'drums overhead r c', 'drum overhead oh left cu grace', 'beatbox soprano cu ssle', 'nbatg   hi hat  ela m', 'hi hat', 'hhat', 'shaker cu api', 'woodblock', 'conga room', 'bongos', 'nbatg   oh hi hat   ela m', 'china', 'drumsride', 'hand claps', 'drums hat ela m', 'pair overheadortf', 'revcrash', 'ac guitar  cu shadowhill .l', 'brassstaccatohi', 'looppercussion', 'metalhit', 'whispers', 'heartbeat', 'bell  tf', 'drums   overhead right   ela m', 'bell drum tf', 'drums   overheads   m.r', 'drums hat ela m', 'overheads alternatetake', 'drums overhead ela m', 'drumsroomstereo rideonly', 'hat', 'sleighbells', 'hammondlesliehi', 'conga lo', 'shaker', 'crashsfx', 'drum ride m', 'djembe', 'drums overhead m', 'overheads liveroom', 'crash', 'sfxhit', 'beatbox group omni u ssle', 'hit', 'timpanihits', 'percussion  m', 'conga stereooverheads', 'crashes', 'overheadmono', 'percsolo farmicpair', 'electrohit', 'drumsoverheads', 'djembe top ar ssle', 'beatbox alto a e ssle', 'drumsoverhead', 'drumkit overheads', 'ac guitar  cu shadowhill.r', 'clave', 'sidestickod overheads', 'triangleandchimes', 'tambourineroom', 'bell', 'drums hat m', 'drumsconga', 'leadvoxdtwhisper', 'overheads m fet.r', 'clapsroom', 'br   drums high hat m gold', 'subhit', 'bell drum close m', 'percchoir micpair', 'drums ride ela m', 'celloharmhi mic', 'kalimba']
#
#
#
# woodwind 66
# ['saxophoneclosemic', 'saxophone', 'ah alto ak ssle', 'sax od', 'saxmic', 'saxophones', 'spotmic sopranos', 'spotmic altos', 'saxmic peerarray', 'outro alto e ssle', 'soprano', 'sopranood', 'saxmic spotmic', 'ah alto e ssle', 'sax b   ak mkii   neve', 'clarinets', 'spotpair woodwind', 'baritone sax m api', 'ah dbl alto ak ssle', 'woodwindstaccato', 'oboes', 'guitar vox alto u ssle', 'sax', 'sax a   ak mkii   neve', 'alto', 'vocals sax m', 'saxbaritone', 'saxalto', 'midisax', 'fluteloop', 'ld vox alto a ac ssle', 'ld vox soprano a  ssle', 'ah soprano u ssle', 'vocals bg sax m', 'mellotronflute', 'ah dbl soprano u ssle', 'woodwindruns', 'ld vox alto b e ssle', 'flute', 'ah dbl soprano cu ssle', 'outro soprano u ssle', 'ld vox soprano b u ssle', 'ld vox alto b ak ssle', 'ld vox soprano a ak ssle', 'clarinet', 'scratch vox alto m ssle', 'ld vox alto a u ssle', 'outro soprano cu ssle', 'ld vox soprano b ac ssle', 'flutes', 'altosaxmic', 'ld vox alto a cu ssle', 'ah dbl alto e ssle', 'saxophonefarmic', 'ld vox soprano a e ssle', 'saxtenor', 'altood', 'adlib alto a ak ssle', 'ethnoflute', 'adlib alto b e ssle', 'outro alto ak ssle', 'ld vox alto b  ssle', 'adlib soprano ac ssle', 'ld vox soprano b cu ssle', 'guitar vox alto cu ssle', 'ah soprano cu ssle']
#
#
#
# keys 89
# ['elecpianosfx', 'clavinet', 'reversepiano', 'piano ak langevin.l', 'vocals keys proto', 'pianospot', 'pianos', 'keys juno pdi', 'rhodesfx', 'keys  passive di', 'keys piano  m', 'keys right   di   lachappel', 'pianomicpair', 'piano close  .r', 'pianoinsidemics', 'keys passive di', 'keys amp m', 'keys leslie m', 'toypiano', 'vocals keys m', 'keys left   di   lachappel', 'spotpair piano', 'pianoreverb', 'keys clav proto', 'keys  active di', 'keys active di', 'piano ak langevin.r', 'keys leslie m.', 'keys leslie top m', 'pianostrings', 'keys moog di', 'pianolo', 'elecpianopad', 'sd keys di grace', 'accordionmic', 'keys b m', 'keys di', 'rhodes', 'accordion', 'vocals keys m', 'keys hammond m', 'pianopad', 'nbatg   rhodes   di', 'keys organ active di', 'keys nord di', 'piano room ar .r', 'piano room ar .l', 'piano a   ela m    neve', 'keys juno passive di', 'pianomics', 'piano liveroom', 'keys leslie bot m', 'vocals bg keys m', 'keys moog pdi', 'piano b   ela m    neve', 'piano', 'vox keys m', 'pianooutsidemics', 'pianodi', 'pianoandstrings', 'keys melodica c', 'keys hammond top m', 'keys di.r', 'pianoroom', 'pianomic', 'keys  di', 'keys toy piano ela m', 'keys', 'keys nord  active di', 'keys piano adi', 'keys hammond passive di', 'keys mininova l passive di', 'piano close  .l', 'keys rhodes adi', 'keys cp active di', 'rhodessfx', 'keys yamaha di', 'pianomid', 'keys b low m', 'keys wurli active di', 'rhodesraw', 'pianosfx', 'elecpiano', 'rhodesdry', 'keys korg sv di', 'keys keyboard ela m', 'room piano u', 'keys mininova r passive di', 'keys di.l']
#
#
#
# hihat 19
# ['hihatride', 'hihatclosed', 'drumkit hihat', 'hihat', 'hihat alternatetake', 'hihatsample', 'hihatod overheads', 'drum hihat  ssl duality', 'loop hihat', 'hihatintro', 'drumkit hihat', 'hihatod', 'hihatopen', 'hihat', 'drumsamples hihat', 'drum hihat  purple biz', 'hihatsfx', 'drumshihat', 'hihat']
#
#
#
# vocal 210
# ['vocals erica m', 'vocals acoustic guitar proto', 'backingvoxdt', 'vox ac guitar c grace', 'leadvoxaccents', 'vocals bone m', 'leadvoxmic', 'backingvoxa', 'leadvoxtapeeffect', 'backingvoxbr', 'leadvox alttake', 'vocals bgv m', 'voxsfx', 'voxguitar', 'vox bg u', 'leadvoxcha', 'leadvoxclose', 'leadvoxvs', 'lead vox b (akg )', 'leadvoxvsdt', 'vocals tim cu', 'vocals lead proto', 'vox mandolin m grace', 'leadvox', 'vocals paul cu', 'group vocals    u   bae', 'vocals lead m', 'vocals vocal m', 'vocals adam proto', 'backing vox a (korby kat c )', 'backingvos', 'leadvoxc', 'lead vox', 'vox    m', 'vocals brian proto', 'chorus vocal   u   bae', 'vocals josh m', 'voxmid', 'backingvoxb singer', 'leadvoxbr', 'voxintro', 'backvox', 'vox  m', 'leadvoxvssfx', 'leadvoxdtmic', 'vox bg cu neve lb clb', 'vocals amy m', 'backingvoxch', 'leadvoxfx', 'vocals bg fiddle proto', 'vox ld cu', 'vox ac guitar m grace', 'electrochoir', 'backingvoxd', 'vocals geneva m', 'vox ld u', 'vocals lead m', 'leadvoxchdt', 'vox mandolin  grace', 'vocals (live scratch) m    api', 'voxadlibs', 'stringschoir', 'vox lead m', 'leadvoxalt untuned', 'backingvoxharmonizer', 'leadvoxdt', 'voxspot u', 'backingvox nopitchprocessing', 'vox wet', 'backingvoxsubmix', 'leadvoxaltdt', 'backingvox untuned', 'backingvoxfemaledt', 'vocalsfx', 'voxbanjo', 'group vocals    c   bae', 'backingvoxfx', 'leadvoxadlibs', 'vocals bg gtr proto', 'vocals lead u', 'vocals steve u', 'lead vocals   u   bae', 'backingvoxa singer', 'vocals byron m', 'leadvoxdt singer', 'vocals bv m', 'lead vox a (akg )', 'backingvoxwet', 'vox   m', 'leadvoxlo', 'leadvoxchorus', 'chorus vocals   c   bae', 'backingvoxdist', 'vox cian m', 'leadvoxchb', 'leadvoxdoubletrack', 'vocals leslie  ela m', 'leadvoxdtlow', 'mobvox', 'leadvoxfar', 'vocals sammi m', 'leadvox untuned', 'backingvoxsfx', 'leadvoxdouble', 'backingvoxb', 'nbatg   lead vox   m', 'voxspot r', 'vocals dave m', 'spot vocals', 'leadvoxraw', 'vocals lead cu', 'leadvoxdt nopitchprocessing', 'scratch vox ld m ssl duality', 'lead vocals   ak kii   bae', 'backing vox b (korby kat c )', 'voxmidalt', 'leadvoxsfx', 'voxsample', 'sd vox guitar m', 'vocals clean m', 'vox sfx', 'lead vocals   ela m    bae', 'vox ld ar', 'leadvoxscratch', 'leadvoxod uncompedtake', 'vocals lead m', 'backingvoxe', 'backingvoxclose', 'backingvoxmalesubmix', 'voxdry', 'backingvoxf', 'nbatg   backing vox   m', 'vox guitar m', 'leadvox isobooth', 'br   vox m purple', 'voxspot vu', 'vocal trevor m', 'vox ld ak vintech laa', 'samplevox', 'leadvoxch', 'leadvox edited', 'vocals main m', 'vocals dan m', 'vocals bg m', 'vocals nick m', 'backingvox singer', 'vox mikaela harp m', 'leadvoxharm', 'vox bg c', 'vox shane m', 'vocals gtr m', 'nbatg   backing vox    m', 'vocals efx shure dx', 'vox guitar  m', 'leadvoxdts', 'leadvox raw', 'leadvoxaccents', 'leadvoxalt', 'backingvoxdt singer', 'vocals banjo proto', 'backingvoxfemale', 'vocals ele guitar m', 'vox ld e', 'vocals guitar proto', 'vox jamie m', 'vocals mando proto', 'leadvoxdoubles', 'voxbothsfx', 'leadvoxa', 'leadvoxduet', 'vox', 'vocals will m', 'vocals mike proto', 'scratch vox bg m ssl duality', 'sd vox bone m', 'leadvoxdt', 'voxfx', 'backingvoxc', 'sd vox lead m', 'vocals kevin proto', 'vox', 'vox dry', 'vocals  m', 'backingvox tuned', 'leadvoxharmdt', 'backingvoxfar', 'leadvox', 'vocals erica proto', 'voxpitchsfx', 'leadvox tuned', 'vocals lead wet m', 'samplechoir', 'backingvox', 'backingvoxmic', 'vox   m sh', 'leadvoxoverdub', 'leadfvox', 'leadvoxb', 'group vocals   c   bae', 'leadvoxdtadlib', 'leadvox singer', 'choir', 'vox', 'voxdt', 'leadvoxkiddie', 'midichoir', 'lead vox   u   neve', 'leadvox nopitchprocessing', 'vocals bv  m', 'vox oooooo m']
#
#
#
# guitar 200
# ['ac guitar', 'elecgtra mic', 'acgtrdi', 'elecgtra close', 'guitar amp    m', 'mandolin ela m', 'acoustic guitar ela m', 'nbatg   acoustic guitar di', 'ele guitar amp m', 'ele guitar amp cu', 'rhythm gtr', 'elecgtrlead', 'acgtrreampfar', 'elecgtrdry', 'e guitar   m', 'elecgtrebow', 'ele guitar  con ak', 'elecgtralttake', 'nylongtr', 'guitar   ar    bae', 'acoustic guitar m', 'mandolin mic m', 'elecgtrb amb', 'gtrmic', 'ele guitar proto', 'acousticgtr remixedit', 'mandolin ak vintech  laa', 'gtrcamp', 'gtr vsdown', 'acousticgtrmic', 'acousticgtrmics', 'acousticgtrdtreverse', 'elecgtr', 'fiddle m', 'gtrb mic', 'elecgtrmic', 'sd guitar m', 'gtr risepatch dark', 'elecgtrdt', 'eguitar tf', 'gtr con', 'acousticgtrb', 'guitar cu', 'gtrdi', 'ac guitar m grace', 'ele guitar  con cu', 'ele guitar con mic ak', 'guitar dave m', 'acgtr', 'slecgtra close', 'lapsteelgtr', 'elecgtrampsim', 'acgtrb closemic', 'elecgtrampmic', 'ele guitar dyn m', 'acoustic guitar leslie ela m', 'elecgtrb mic', 'ele gtr dis m', 'br   guitar m orange', 'elecgtrmics', 'guitar dynamic jon m', 'elecgtrc mic', 'gtr sectiond light', 'ele guitar dyn mic m', 'elecgtrb di', 'guitar msh', 'ukulele e ssle', 'guitar   ak mkii   bae', 'e guitar  m', 'acgtra closemic', 'elecgtramp', 'guitar   cu', 'gtr solo', 'e guitar m chandler tg channel', 'ele guitar  m', 'accgtr', 'acoustigtr', 'guitarmarimba', 'guitar condenser tory cu', 'ele guitar jesse proto', 'ukulele', 'gtr  tf', 'mandolin m grace', 'ele guitar amp cu', 'ele guitar  con ar', 'elecgtrd di', 'eelcgtr', 'elecgtrc', 'gtr risepatch light', 'acousticgtrreverse', 'midiguitar', 'gtrb', 'e guitar   ar    presonus m', 'gtr sectiond dark', 'acousticgtrdi', 'ac guitar cu', 'scractch ac guitar di ssl duality', 'gtrd mic', 'ele guitar clean m', 'ele guitar con ak', 'guitar   m (stock)   bae', 'acguitar', 'ele guitar con ar', 'ele guitar  dyn m', 'e guitar ar chandler tg channel', 'e guitar  m api', 'elecgtrclosemic', 'acousticgtrclosemics', 'guitar   cu  copperhead   bae', 'gtr sectionc light', 'eguitar    (palmer pdi)', 'elecgtrd', 'guitar m (m instrument prototype)   bae', 'ac guitar di ssl duality', 'elecgtrb amp', 'acousticgtr', 'elecgtrdidt', 'ac guitar ar', 'guitar craig m', 'e guitar cu chandler tg channel', 'ele guitar amp m', 'guitarfar', 'acoustic guitar guitar m', 'guitar m', 'guitar   m sh', 'acousticgtrmic', 'fiddle', 'mandolin di', 'electric guitar  m sh', 'elecgtrd', 'ele guitar shelf mic ar', 'gtradi', 'elecgtrfar', 'acoustic guitar active di', 'mandolin', 'ele guitars jon m', 'ele guitar con cu', 'acgtrreampclose', 'elecgtrmicdi', 'gtramp', 'ele guitar mike proto', 'climbingtree', 'elecgtrdimic', 'ele guitar dis m', 'acousticgtrdt', 'ele guitar con m', 'ukulele  ssle', 'acgtrmic', 'acoustic guitar proto', 'elecgtra di', 'slidegtr', 'guitar', 'acousticgtramp', 'ele guitar dyn m', 'acousticgtrdi', 'elecgtrdtdi', 'fiddle  neve lb clb', 'elecgtra', 'eelcgtrdt', 'gtr vsup', 'acgtr mic', 'elecgtrb fuzz', 'acoustic guitar adi', 'guitar condenser jon cu', 'guitarclose', 'midigtr', 'mandolinmic', 'gtr  m', 'elecgtrdtmic', 'elecgtrc di', 'acousticgtrfarmics', 'aco guitar ela m', 'elecgtrmc', 'gtr dyn', 'acousticgtra', 'elecgtra amp', 'gtra mic', 'ele guitar proto', 'ele guitars troy m', 'elecgtrclose', 'gtrbamp', 'acoustic guitar ela m', 'elecgtrb', 'gtrc mic', 'elecgtrdi', 'fiddlesmic', 'gtra', 'nbatg   electric guitar   m', 'gtr', 'acoustic guitar lead ela m', 'ele guitar tf', 'gtr sectionc dark', 'fiddle ak vintech  laa', 'ele guitars ignater m', 'ele guitar m', 'acoustic guitar ar', 'acoustic guitar steve cu', 'guitar dynamic tory msh', 'ele guitar clean tf', 'elecgtrdtamp']
#
#
#
# drum 110
# ['drum oh ar langevin.l', 'drumkit roommono', 'drumssider', 'drumkit', 'drumsbreak', 'drums  oh l m api', 'drumssansamp', 'drumkitclose', 'drums over tf', 'drumsrioom', 'drums drum shell u', 'drummic', 'drums over head ela m', 'drumssfx', 'drumkit drumssquashmic', 'drumfills', 'drumkit room', 'sd drums ak api', 'drum room', 'exodrum', 'drumsreverb', 'drums over tf.', 'drum room u api smartc.l', 'drums over far tf', 'drumamb', 'drumsroommono', 'drumkitroom', 'sd drums room m api', 'drums over ar', 'drums over m', 'drumsroomlofi', 'drumssfxfar', 'vox drums m', 'drumsroomfx', 'drumswurstmic', 'drums floor mic m', 'drumkit trashmic', 'drumssfxclose', 'drumsroomtriggers', 'drums sample passive di', 'drums', 'drums  oh r m api', 'drums over far proto', 'drumfill', 'br   drums mpc', 'drums floor m', 'drums rack cu', 'drumsroom stereo', 'drums room m.', 'drum oh ak ssl duality.r', 'loopdrums', 'drumssquashmic', 'drumroom', 'drums chamber  ar', 'drumsroomod', 'drum oh ar langevin.r', 'drums floor  m', 'drum oh c ssl duality.l', 'drum oh c ssl duality.r', 'drumloop', 'romanwardrum', 'drums floor m.', 'drums mono over ar', 'drumsslr', 'drums room m', 'drumsroomclose', 'drumsamb', 'steeltonguedrum', 'drums wvo  ar', 'drumsambience', 'drums over head m', 'sd drums hall ar api', 'drumsleakage', 'drumsroommonofx', 'drum', 'drums over close ela m', 'drumkit roomstereo', 'drumsroom', 'drum room u api smartc.r', 'drum fat head millenia hv', 'vocals drums m', 'drums room l cu', 'elecdrum', 'drums rack  m', 'drums chamber ar', 'drumssidel', 'drums chamber m', 'drum oh tf stereo set', 'drumsroomfar', 'drumsroomstereointro', 'drumkitlayer', 'drumsroomstereo', 'drums room r cu', 'impactdrums', 'drumspzm', 'drums spd sx passive di', 'drum room celling crown pzm hardey m', 'drums mono over cu', 'drumloop', 'drum oh ak ssl duality.l', 'drumsleakage alternatetake', 'drum room   u    bae', 'drumscrush', 'bassdrum', 'drums rack m', 'drumsverb', 'drums mono cu', 'drumssquash', 'drumsroom alternatetake', 'drumsroom mono']
#
#
#
# tom 70
# ['leslie bottom m', 'drumstom', 'floortom', 'drum rack tom m ssl duality', 'tom', 'tom', 'drum toms  m sh api', 'drums floor tom cu', 'tomfx', 'drums   tom    m sh', 'drums tom m', 'drums floor tom m', 'tom  m sh', 'drum floor tom m ssl duality', 'drums rack tom m.', 'tom    m   api', 'tomscymbals', 'rototom', 'tomsamples', 'djembe bottom  ssle', 'tomsod overheads', 'nbatg   floor tom   m', 'drums floor tom  m.', 'tomhi', 'stomp', 'tomtrigger', 'drums rack tom  m.', 'drum rack tom m sh', 'perc toms .', 'tomlo', 'drum tom  akg  toft afc', 'sidestickod tom', 'organ leslie bottom m', 'racktom', 'drum floor tom  m', 'drumkit tom', 'drumkit toms', 'keys hammond bottom cu', 'drumsfloortom', 'sd drums tom  m sh api', 'tomroll', 'tomesample', 'tomsod room', 'tomsample', 'drums tom  m api', 'drums rack tom proto', 'stomps', 'drumsamples toms', 'drums rack tom m', 'tomsod tom', 'toms', 'drum tom m sh api', 'tomup', 'tom', 'tomod', 'nbatg   rack tom   m', 'keys leslie bottom m', 'toms liveroom', 'perc toms room.', 'drums   tom   m sh', 'drums   floor tom   m sh', 'drums tom m samp', 'tom alternatetake', 'drumsroomstereo tomsonly', 'drumkittom', 'toms sfx', 'sd drums tom m sh api', 'toms', 'tomdown', 'drums floor tom proto']
#
#
#
# fx 25
# ['sfxloop', 'vocoderfx', 'samplesfx', 'gtr vssfx light', 'stormsfx', 'sfxintro', 'elecgtrfx', 'catsfx', 'sfxwet', 'sfxwolf', 'mandolinsfx', 'loopsfx', 'cartoon sfx', 'sfx guiness', 'reversesfx', 'elecgtrsfx', 'sfxlaugh', 'harpsfx remixaddition', 'acousticgtrfx', 'noisesweep sfx', 'sfx', 'gtr vssfx dark', 'sfxdry', 'sfx', 'gtrrevsfxmic']
#
#
#
# room 53
# ['roommono', 'room stereo l   c w tfunk ck   neve', 'roomlofi', 'elecgtrb room', 'room a   ar    chandler germanium   distressor', 'room ab    right', 'room left   m', 'rooms', 'monoroom', 'nbatg   room mic left   ela m  (fet prototype)', 'loop room', 'room stereo', 'guitar room   u   bae', 'acgtrc room', 'room ela m e', 'roommic', 'room mono', 'room b   ar    chandler germanium   distressor', 'close room m', 'room l ela m', 'classroomambience', 'elecgtrroom', 'distant room right  ar stereo grace', 'room ela m', 'room xy   ar  stereo', 'room right   m', 'room a   beyer dynamic    neve', 'room ar', 'room ar', 'nbatg   room mic right   ela m  (fet prototype)', 'roomstereo', 'room ab    left', 'saxophoneroom', 'room left m api', 'room ar  (cardioid)', 'room b   beyer dynamic    neve', 'wide room  tf', 'room d   beyer dynamic    neve', 'room ms mid cardioid ar  stereo', 'distant room left  ar stereo grace', 'room d   ar    chandler germanium', 'room stereo r   c w tfunk ck   neve', 'room c   beyer dynamic    neve', 'saxophone liveroom', 'room r ela m', 'room c   ar    chandler germanium', 'room u', 'leadvoxroom', 'room right m api', 'room', 'room ms side figure  ar  stereo', 'elecgtrroommic', 'room m']
#
#
#
# other 254
# ['bulldozer', 'officeambience', 'ukelelemic', 'loops', 'chamber ar', 'runningasiza', 'clicks', 'paul amp m', 'idiophone', 'treechopfall', 'dobro', 'paliteo', 'leslie right   m', 'diabara', 'banjo di', 'mainpair msdecoded', 'introclose', 'kt. hh', 'bombek', 'yamaha', 'acoustic di', 'mellotron', 'dobro ar daking distressor.r', 'leslie left   m', 'knocking', 'harpharmonics', 'lyricaloctave', 'sidestick', 'beep', 'timbales', 'psaltery', 'sticks', 'dnaredown', 'sampler di', 'theme', 'breaks', 'gidamba', 'drip', 'pizz', 'closemicleft', 'm left', 'narration', 'dulcimer', 'fill', 'rainstick', 'lakeambience', 'ukeleledi', 'squashmic', 'sample', 'autoharp', 'dulcimers', 'guitalele', 'gangs', 'closemicright', 'stumblingwood', 'sn b', 'shekere m', 'themedt', 'guasa', 'sprinkles', 'glitch', 'radio', 'vinylnoise', 'breath', 'glup', 'hammondlo', 'leslie top m sh', 'moog', 'partywalla', 'nbatg   stage lip   ar', 'loop', 'nord electro r di', 'taiko', 'pandeiro', 'bone', 'door', 'recordier', 'banjomic', 'dobro ar daking distressor.l', 'key right di', 'asizagiggles', 'k i', 'nord r di', 'chug', 'leaddouble', 'chamber', 'orchstabs', 'harp amp tf', 'keyboard', 'clav', 'pandero', 'mainmics', 'key left di', 'mainloop', 'ivo', 'keyboard m api', 'di', 'hammondmiclo', 'laugh', 'telephone', 'egutiar    (earthworks sr)', 'loop trashmic', 'oh right   cu  copperhead   bae', 'glock', 'music', 'chamber m', 'tenorod', 'flock', 'telefunken sovoso all starts singer b', 'vibraslap', 'nord l di', 'spotmic tenors', 'vibrophone', 'accordian', 'brushes', 'fingerclicks', 'speech', 'cajonmic', 'storm', 'arcorhythm', 'vibraslap', 'sidesticksample', 'click', 'rain', 'anvil', 'oh xy right   ar  stereo   bae', 'cunonosample', 'bombo', 'banjo ak vintech', 'banjo m grace', 'introfar', 'piccolo', 'banjo', 'banjo cu', 'traffic', 'vocoder', 'm right', 'heartbeart', 'xylophone', 'oh left   cu  copperhead   bae', 'mainpair', 'harmonica', 'pair frontms', 'noise', 'pedalsteel', 'timbale', 'musicbox', 'dun dun set tf', 'nord electro l di', 'oh xy left   ar  stereo   bae', 'tambo', 'hammond', 'telefunken sovoso all stars singer a', 'marimba', 'celesta', 'guaracha', 'pano b   ela m    neve', 'mainpair ab', 'llenties', 'mainxypair', 'scream', 'subdrop', 'forestambience', 'gunshot', 'voicemail', 'themecounter', 'tamb', 'tamborine cu api', 'panderodt', 'ham b', 'hammondleslielo', 'leslie low   m', 'farfisa', 'k o', 'outriggerpair', 'key di', 'rimshot', 'decks', 'harp di', 'dun dun extra  m', 'pad', 'ela m  ac', 'rde', 'dun dun   m', 'asizasobbing', 'guarachacumbia', 'over', 'adlib tenor cu ssle', 'toycar', 'tracks active di', 'oh left   elam    bae', 'cunono', 'daiko', 'stumblinggrass', 'revcymb', '', 'fills', 'llamador', 'kck', 'paul di', 'scratch', 'vibes', 'banjo cu vintech', 'asizarunningsnow', 'adlibs', 'tenor', 'adlib group omni u ssle', 'srtings', 'hallpair', 'sampleharp', 'sanresample', 'nord', 'hammondraw', 'cachapas', 'euphoniiums', 'lightning', 'lyricaldt', 'winterforestambience', 'noisesweep', 'footsteps', 'stylophone', 'clonk', 'runningrobert', 'harp amp m', 'steelpans', 'wurlitzer', 'dun dun  m', 'lyrical', 'harp', 'ham top', 'elecgttdt', 'orchestra', 'sitar', 'cajon', 'intro', 'impact', 'guache', 'alarm', 'mainpair dominantarray', 'rimshot', 'dun dun  m', 'oh right   elam    bae', 'sn t', 'didgeridoo', 'steelpansdt', 'adlib group omni  ssle', 'elecgtt', 'toyhelicopter', 'blumlein ar', 'timp', 'tim amp m', 'break', 'ukelele', 'subboom']
#
#
#
# string 65
# ['midistrings', 'violasamples', 'stringspizz', 'midiviolin', 'cellosamples', 'strings violin active di', 'violasb', 'cello m', 'strings ensemble', 'cellos', 'violasa', 'cellos micpair', 'stringssfx', 'strings staccato', 'cellosb', 'spot cello', 'cellomidi', 'violinsa', 'stringsloop', 'violindi', 'cellosa', 'strings', 'violas', 'midiviolas', 'violinsamples', 'violinslegato', 'reversestrings mic', 'spot violin', 'stringspizzicato', 'stringstunedmix', 'strings cellosclosemic', 'violasstaccato', 'spot viola', 'violasolodist', 'celloharmlo mix', 'cellos closemic', 'strings micpair', 'spot lowstrings', 'cellobridge', 'strings sectionmic vla', 'strings sectionmic cello', 'violinsolo', 'cellosolo', 'violasoloraw', 'celloharmlo mic', 'strings violin m', 'cellomic', 'violamidi', 'strings soli', 'violastrills', 'viola', 'violinsb', 'violinmic', 'strings sectionmic vlni', 'violin', 'violinmidi', 'violin c', 'strings sectionmic vln', 'soloviolin', 'violinsstaccato', 'cello', 'violins', 'violas remixaddition', 'celloslegatoandtrills', 'stringsmix']
#
#
#
# synth 29
# ['synthfx', 'synth', 'synthpad', 'synth remixaddition', 'synthd', 'synthfill', 'synth sfx', 'synthmel', 'synthsaw', 'synthb', 'br   synth virus', 'synthc', 'synthfiddle', 'synthchoir', 'synth pitchmodulated', 'synth unmodulated', 'synthstrings', 'synthdry', 'synthwet', 'br   synth moog', 'keys synth di', 'syntharp', 'synths', 'syntha', 'synthsfx', 'synthstabs', 'synthlead', 'synthdt', 'pianosynth']
#
#
#
# organ 15
# ['organ vox alto u ssle', 'organ vox tenor ak ssle', 'organ leslie top m sh.l', 'organ vox alto cu ssle', 'organ dbl vox tenor e ssle', 'organsfx', 'organ leslie top m sh.r', 'organ vox tenor e ssle', 'organ right   m sh', 'organ', 'organ dbl vox alto u ssle', 'organ dbl vox alto cu ssle', 'organ left   m sh', 'organ dbl vox tenor ak ssle', 'organ low   m']
